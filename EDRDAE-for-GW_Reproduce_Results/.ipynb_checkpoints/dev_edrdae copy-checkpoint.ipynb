# %%
# EDRDAE Model

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import h5py
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import functions as f

# %%
dataset = h5py.File('./dataset/data_both.h5', 'r')
train = np.array(dataset['train'])
test = np.array(dataset['test'])

# %%
tes = f.roll_signal(test[0:10], 9)
unrolled = f.unroll_signal(tes, num_samples=10, timesteps=9)
# Out:
# (12920, 9)
# (10, 1300)

# %%
for i in range(2):
    fig = plt.figure(figsize=(8,2)) 
    plt.plot(test[0:10][i])
    plt.plot(unrolled[i]+0.1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, TimeDistributed


# Custom layer for scalar multiplication to use as signal amplifier
class ScalarMultiplyLayer(layers.Layer):
    def __init__(self):
        super(ScalarMultiplyLayer, self).__init__()
        self.scalar = self.add_weight(shape=(1,), initializer='ones', trainable=True)

    def call(self, inputs):
        return inputs * self.scalar

# Define the EDRDAE model architecture
# Paper describes: one encoder layer followed by two decoder
# layers with bidirectional LSTM cells
def build_edrdae_model(input_shape, num_channels):
    model = keras.Sequential()
    print('DEBUG: ', input_shape)
    


    # Encoder
    encoder = layers.Bidirectional(layers.LSTM(num_channels, return_sequences=True), input_shape=input_shape)
    model.add(encoder)

    # Hidden layers
    #for _ in range(num_layers):
    #    hidden_layer = layers.Bidirectional(layers.LSTM(num_channels, return_sequences=True))
    #    model.add(hidden_layer)
    
    # Decoder
    decoder_layer1 = layers.Bidirectional(layers.LSTM(num_channels, return_sequences=True))
    model.add(decoder_layer1)
    decoder_layer2 = layers.Bidirectional(layers.LSTM(num_channels, return_sequences=True))
    model.add(decoder_layer2)

    # Signal Amplifier
    #signal_amplifier = layers.Dense(num_channels, activation='relu')
    #model.add(signal_amplifier)


    
    model.add(TimeDistributed(Dense(1, activation='linear')))

    # Signal Amplifier
    model.add(ScalarMultiplyLayer())
    
    return model


# Define the model parameters
timesteps = 9  # (timestep of 9 was best in paper)
num_layers = 4  # Number of decoder layers, (4 best in paper)
num_channels = 64  # Number of channels for LSTM cells

# Reshape the input shape to match the training data
input_shape = (timesteps, 1)

# Build the EDRDAE model
model = build_edrdae_model(input_shape, num_channels)



# Compile the model
lr = 0.0001  # learning rate
adam = keras.optimizers.Adam(learning_rate=lr)
model.compile(optimizer=adam, loss='mse')
# Out:
# DEBUG:  (9, 1)

# %%
len(train)
# Out:
# 9861

# %%
batch_size_ = 30000


# Curriculum Learning
initial_snr = 2.0  # Initial Signal-to-Noise Ratio (SNR)
final_snr = 0.45  # Final SNR
num_iterations = 2000  # Number of iterations for each SNR level
num_steps = 10  # Number of steps to gradually decrease the SNR

earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="loss",
    min_delta=0.0001,
    patience=10,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

full_history = []
for step in range(num_steps):
    current_snr = initial_snr - (step * (initial_snr - final_snr) / num_steps)
    print(f"Training with SNR: {current_snr}")
    
    shifted = f.shift_data(train)
    # Generate noisy training data with current SNR
    noisy = f.add_gaussian_noise(shifted.copy(), current_snr)

    shifted_rolled = f.roll_signal(shifted, timesteps)
    noisy_rolled = f.roll_signal(noisy, timesteps)
    
    
    #print(x_train_noisy.shape, just_test.shape)
    y_train = shifted_rolled.reshape((shifted_rolled.shape[0], timesteps, 1))
    x_train = noisy_rolled.reshape((noisy_rolled.shape[0], timesteps, 1))

    print(x_train.shape, y_train.shape)

    # Train the model with current SNR
    history = model.fit(x_train, y_train, batch_size=batch_size_, callbacks= [earlystop], epochs=num_iterations, verbose=1)

    full_history.append([current_snr, history])
# Out:
# Training with SNR: 2.0
# (12740412, 9)
# (12740412, 9)
# (12740412, 9, 1) (12740412, 9, 1)
# Epoch 1/2000
# 425/425 [==============================] - 61s 120ms/step - loss: 0.2629
# Epoch 2/2000
# 173/425 [===========>..................] - ETA: 30s - loss: 0.2525
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 40
#      37 print(x_train.shape, y_train.shape)
#      39 # Train the model with current SNR
# ---> 40 history = model.fit(x_train, y_train, batch_size=batch_size_, callbacks= [earlystop], epochs=num_iterations, verbose=1)
#      42 full_history.append([current_snr, history])
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1691, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1689 logs = tmp_logs
#    1690 end_step = step + data_handler.step_increment
# -> 1691 callbacks.on_train_batch_end(end_step, logs)
#    1692 if self.stop_training:
#    1693     break
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/keras/callbacks.py:475, in CallbackList.on_train_batch_end(self, batch, logs)
#     468 """Calls the `on_train_batch_end` methods of its callbacks.
#     469
#     470 Args:
#     471     batch: Integer, index of batch within the current epoch.
#     472     logs: Dict. Aggregated metric results up until this batch.
#     473 """
#     474 if self._should_call_train_batch_hooks:
# --> 475     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/keras/callbacks.py:322, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     320     self._call_batch_begin_hook(mode, batch, logs)
#     321 elif hook == "end":
# --> 322     self._call_batch_end_hook(mode, batch, logs)
#     323 else:
#     324     raise ValueError(
#     325         f"Unrecognized hook: {hook}. "
#     326         'Expected values are ["begin", "end"]'
#     327     )
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/keras/callbacks.py:345, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     342     batch_time = time.time() - self._batch_start_time
#     343     self._batch_times.append(batch_time)
# --> 345 self._call_batch_hook_helper(hook_name, batch, logs)
#     347 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     348     end_hook_name = hook_name
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/keras/callbacks.py:393, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     391 for callback in self.callbacks:
#     392     hook = getattr(callback, hook_name)
# --> 393     hook(batch, logs)
#     395 if self._check_timing:
#     396     if hook_name not in self._hook_times:
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/keras/callbacks.py:1093, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1092 def on_train_batch_end(self, batch, logs=None):
# -> 1093     self._batch_update_progbar(batch, logs)
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/keras/callbacks.py:1169, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1165     self.seen += add_seen
#    1167 if self.verbose == 1:
#    1168     # Only block async when verbose = 1.
# -> 1169     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1170     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/keras/utils/tf_utils.py:680, in sync_to_numpy_or_python_type(tensors)
#     677         return t
#     678     return t.item() if np.ndim(t) == 0 else t
# --> 680 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/keras/utils/tf_utils.py:673, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     670 def _to_single_numpy_or_python_type(t):
#     671     # Don't turn ragged or sparse tensors to NumPy.
#     672     if isinstance(t, tf.Tensor):
# --> 673         t = t.numpy()
#     674     # Strings, ragged and sparse tensors don't have .item(). Return them
#     675     # as-is.
#     676     if not isinstance(t, (np.ndarray, np.generic)):
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1160, in _EagerTensorBase.numpy(self)
#    1137 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1138
#    1139 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1157     NumPy dtype.
#    1158 """
#    1159 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1160 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1161 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1126, in _EagerTensorBase._numpy(self)
#    1124 def _numpy(self):
#    1125   try:
# -> 1126     return self._numpy_internal()
#    1127   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1128     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.models import load_model

# %%
model.save('rnn_model_attempt_0.h5')

# %%
#model = load_model('./test_train.h5')

# %%
snr = 0.5

# %%
test_noisy = add_gaussian_noise(test, snr)

# %%
# %%time
predictions = model.predict(test_noisy, batch_size=300)
predictions = predictions.reshape(predictions.shape[0], predictions.shape[1])

# %%
predictions.shape

# %%
for i in range(100):
    fig = plt.figure(figsize=(10,2))
    plt.title('SNR: ' + str(snr))
    #plt.plot(test_noisy[i], color='gray',  alpha=0.3)
    plt.plot(predictions[i], color='m', label='pred')
    plt.plot(test[i], color='blue', label='target')
    plt.legend()
    plt.show()
